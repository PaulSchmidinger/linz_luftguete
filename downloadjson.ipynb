# %%
import requests
import json
import datetime

# %%
#logging

def log(message):
    timestamp_format = '%Y-%h-%d-%H:%M:%S-%Z'
    now = datetime.datetime.now()
    timestamp = now.strftime(timestamp_format)
    with open('jsondump/jsondump.log','a') as f:
        f.write(timestamp + ';' + message + '\n')

# %%
APIs = {
    "Linz 24er-Turm":"https://www2.land-oberoesterreich.gv.at/imm/jaxrs/messwerte/json?stationcode=S415",
    "Linz Chemiepark":"https://www2.land-oberoesterreich.gv.at/imm/jaxrs/messwerte/json?stationcode=C001",
    "Linz Goethestraße":"https://www2.land-oberoesterreich.gv.at/imm/jaxrs/messwerte/json?stationcode=L001",
    "Linz Neue Welt":"https://www2.land-oberoesterreich.gv.at/imm/jaxrs/messwerte/json?stationcode=S416",
    "Linz Römerberg":"https://www2.land-oberoesterreich.gv.at/imm/jaxrs/messwerte/json?stationcode=S431",
    "Linz Schlossmuseum":"https://www2.land-oberoesterreich.gv.at/imm/jaxrs/messwerte/json?stationcode=L002",
    "Linz Stadtpark":"https://www2.land-oberoesterreich.gv.at/imm/jaxrs/messwerte/json?stationcode=S184",
    "Linz Sternwarte":"https://www2.land-oberoesterreich.gv.at/imm/jaxrs/messwerte/json?stationcode=L003",
    "Freinberg-Sender":"https://www2.land-oberoesterreich.gv.at/imm/jaxrs/messwerte/json?stationcode=S425"
}

# %%
now = datetime.datetime.now().strftime("%Y_%m_%d_%H_%M")

for key in APIs:
    try:
        response = requests.get(APIs[key])
        data = response.json()
        #save data to file
        with open("jsondump/"+now+"_"+key+".json", "w") as outfile:
            json.dump(data, outfile)
        #log
        print(key, ": ", APIs[key])
        print(data)
        log(key + " " + APIs[key])
    except:
        print(key, "Error")
        log(key + " Error")
# Out:
# Linz 24er-Turm :  https://www2.land-oberoesterreich.gv.at/imm/jaxrs/messwerte/json?stationcode=S415
# {'messwerte': [{'zeitpunkt': 1700325000000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '1,64'}, {'zeitpunkt': 1700326800000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '2,96'}, {'zeitpunkt': 1700328600000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '3,67'}, {'zeitpunkt': 1700330400000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '4,08'}, {'zeitpunkt': 1700332200000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '3,77'}, {'zeitpunkt': 1700334000000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '3,75'}, {'zeitpunkt': 1700335800000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '3,47'}, {'zeitpunkt': 1700337600000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '2,83'}, {'zeitpunkt': 1700339400000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '3,16'}, {'zeitpunkt': 1700341200000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '2,24'}, {'zeitpunkt': 1700343000000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '1,65'}, {'zeitpunkt': 1700344800000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '1,51'}, {'zeitpunkt': 1700346600000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '1,08'}, {'zeitpunkt': 1700348400000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '1,5'}, {'zeitpunkt': 1700350200000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '1,06'}, {'zeitpunkt': 1700352000000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '1,41'}, {'zeitpunkt': 1700353800000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '3,36'}, {'zeitpunkt': 1700355600000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '3,09'}, {'zeitpunkt': 1700357400000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '3,76'}, {'zeitpunkt': 1700359200000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '4,44'}, {'zeitpunkt': 1700361000000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '3,55'}, {'zeitpunkt': 1700362800000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '3,65'}, {'zeitpunkt': 1700364600000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '2,33'}, {'zeitpunkt': 1700366400000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '1,73'}, {'zeitpunkt': 1700368200000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '1,68'}, {'zeitpunkt': 1700370000000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '1,22'}, {'zeitpunkt': 1700371800000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '0,95'}, {'zeitpunkt': 1700373600000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '0,71'}, {'zeitpunkt': 1700375400000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '0,73'}, {'zeitpunkt': 1700377200000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '0,86'}, {'zeitpunkt': 1700379000000, 'station': 'S415', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwer ...
# Linz Chemiepark Error
# Linz Goethestraße :  https://www2.land-oberoesterreich.gv.at/imm/jaxrs/messwerte/json?stationcode=L001
# {'messwerte': [{'zeitpunkt': 1700324100000, 'station': 'L001', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-16,57'}, {'zeitpunkt': 1700324160000, 'station': 'L001', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-16,83'}, {'zeitpunkt': 1700324220000, 'station': 'L001', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-17,030001'}, {'zeitpunkt': 1700324280000, 'station': 'L001', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-17,15'}, {'zeitpunkt': 1700324340000, 'station': 'L001', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-17,33'}, {'zeitpunkt': 1700324400000, 'station': 'L001', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-17,299999'}, {'zeitpunkt': 1700324460000, 'station': 'L001', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-17,299999'}, {'zeitpunkt': 1700324520000, 'station': 'L001', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-17,33'}, {'zeitpunkt': 1700324580000, 'station': 'L001', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-17,35'}, {'zeitpunkt': 1700324640000, 'station': 'L001', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-17,33'}, {'zeitpunkt': 1700324700000, 'station': 'L001', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-17,559999'}, {'zeitpunkt': 1700324760000, 'station': 'L001', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-17,73'}, {'zeitpunkt': 1700324820000, 'station': 'L001', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-17,700001'}, {'zeitpunkt': 1700324880000, 'station': 'L001', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-17
 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwer ...
# Linz Sternwarte :  https://www2.land-oberoesterreich.gv.at/imm/jaxrs/messwerte/json?stationcode=L003
# {'messwerte': [{'zeitpunkt': 1700324100000, 'station': 'L003', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-15,47'}, {'zeitpunkt': 1700324160000, 'station': 'L003', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-15,78'}, {'zeitpunkt': 1700324220000, 'station': 'L003', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-15,78'}, {'zeitpunkt': 1700324280000, 'station': 'L003', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-15,72'}, {'zeitpunkt': 1700324340000, 'station': 'L003', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-16,18'}, {'zeitpunkt': 1700324400000, 'station': 'L003', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-16,1'}, {'zeitpunkt': 1700324460000, 'station': 'L003', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-16,209999'}, {'zeitpunkt': 1700324520000, 'station': 'L003', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-16,440001'}, {'zeitpunkt': 1700324580000, 'station': 'L003', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-16,709999'}, {'zeitpunkt': 1700324640000, 'station': 'L003', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-16,58'}, {'zeitpunkt': 1700324700000, 'station': 'L003', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-17,09'}, {'zeitpunkt': 1700324760000, 'station': 'L003', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-17,26'}, {'zeitpunkt': 1700324820000, 'station': 'L003', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-17,360001'}, {'zeitpunkt': 1700324880000, 'station': 'L003', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-17,26'}, {'zeitpunkt': 1700324940000, 'station': 'L003', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-17,33'}, {'zeitpunkt': 1700325000000, 'station': 'L003', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-17,35'}, {'zeitpunkt': 1700325060000, 'station': 'L003', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-17,26'}, {'zeitpunkt': 1700325120000, 'station': 'L003', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-17,07'}, {'zeitpunkt': 1700325180000, 'station': 'L003', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-16,84'}, {'zeitpunkt': 1700325240000, 'station': 'L003', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-17,08'}, {'zeitpunkt': 1700325300000, 'station': 'L003', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-17,24'}, {'zeitpunkt': 1700325360000, 'station': 'L003', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-17,15'}, {'zeitpunkt': 1700325420000, 'station': 'L003', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-17,25'}, {'zeitpunkt': 1700325480000, 'station': 'L003', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-17,41'}, {'zeitpunkt': 1700325540000, 'station': 'L003', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-17,450001'}, {'zeitpunkt': 1700325600000, 'station': 'L003', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-17,07'}, {'zeitpunkt': 1700325660000, 'station': 'L003', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-16,959999'}, {'zeitpunkt': 1700325720000, 'station': 'L003', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-17,25'}, {'zeitpunkt': 1700325780000, 'station': 'L003', 'komponente': 'LichtMag', 'mittelwert': 'MMW', 'einheit': 'mag', 'messwert': '-17,690001'}, {'zeitpunkt':  ...
# Freinberg-Sender :  https://www2.land-oberoesterreich.gv.at/imm/jaxrs/messwerte/json?stationcode=S425
# {'messwerte': [{'zeitpunkt': 1700325000000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '1,6604'}, {'zeitpunkt': 1700326800000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '0,87389'}, {'zeitpunkt': 1700328600000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '1,7478'}, {'zeitpunkt': 1700330400000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '1,9226'}, {'zeitpunkt': 1700332200000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '1,6604'}, {'zeitpunkt': 1700334000000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '1,4856'}, {'zeitpunkt': 1700335800000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '2,0099'}, {'zeitpunkt': 1700337600000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '2,1847'}, {'zeitpunkt': 1700339400000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '2,1847'}, {'zeitpunkt': 1700341200000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '1,9226'}, {'zeitpunkt': 1700343000000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '1,3982'}, {'zeitpunkt': 1700344800000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '1,3982'}, {'zeitpunkt': 1700346600000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '1,0487'}, {'zeitpunkt': 1700348400000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '1,3982'}, {'zeitpunkt': 1700350200000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '1,9226'}, {'zeitpunkt': 1700352000000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '2,8838'}, {'zeitpunkt': 1700353800000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '2,6217'}, {'zeitpunkt': 1700355600000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '3,7577'}, {'zeitpunkt': 1700357400000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '3,4956'}, {'zeitpunkt': 1700359200000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '2,8838'}, {'zeitpunkt': 1700361000000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '2,7964'}, {'zeitpunkt': 1700362800000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '2,6217'}, {'zeitpunkt': 1700364600000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '2,7964'}, {'zeitpunkt': 1700366400000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '2,3595'}, {'zeitpunkt': 1700368200000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '2,7091'}, {'zeitpunkt': 1700370000000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '2,8838'}, {'zeitpunkt': 1700371800000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '2,4469'}, {'zeitpunkt': 1700373600000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '2,2721'}, {'zeitpunkt': 1700375400000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '1,2234'}, {'zeitpunkt': 1700377200000, 'station': 'S425', 'komponente': 'BOE', 'mittelwert': 'HMW', 'einheit': 'm/s', 'messwert': '0,61172'}, {'zeitpunkt': 1700379000000, 'station': 'S425', 'komp ...
